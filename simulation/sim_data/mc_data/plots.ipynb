# %% [markdown]
# ## Sine Wave Generator Plots

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

pd.set_option('display.float_format', lambda x: '%e' % x)

vout1 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_1.txt')
vout2 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_2.txt')
vout3 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_3.txt')
vout4 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_4.txt')
vout5 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_5.txt')
vout6 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_6.txt')
vout7 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_7.txt')
vout8 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_8.txt')
vout9 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_9.txt')
vout10 = pd.read_fwf('~/VLSI_Sine_Gen/simulation/sim_data/register_dac_mc_10.txt')
fig, ax = plt.subplots()
vout1.plot(y='v(Vout+)-v(Vout-)', ax = ax, title = 'Monte Carlo Simulation of Sine Wave Voltage Output')
vout2.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout3.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout4.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout5.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout6.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout7.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout8.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout9.plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout10.plot(y='v(Vout+)-v(Vout-)', ax = ax)
plt.xlabel('Time (0.1 ns)')
plt.ylabel('Vout (V)')
plt.savefig("sin_wave_gen_vout.svg", format="svg")

# %%
fig, ax = plt.subplots()
vout1.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax, title = 'Monte Carlo Simulation of Sine Wave Voltage Output')
vout2.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout3.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout4.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout5.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout6.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout7.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout8.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout9.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
vout10.loc[500:].plot(y='v(Vout+)-v(Vout-)', ax = ax)
plt.xlabel('Time (0.1 ns)')
plt.ylabel('Vout (V)')
plt.savefig("sin_wave_gen_vout.svg", format="svg")
